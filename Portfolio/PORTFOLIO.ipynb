# %% [markdown]
# # Portfolio

# %% [markdown]
# ### Environment
# - CPU: for sklearn package
# - GPU | CUDA 12.0: for deep learning

# %% [markdown]
# ### Data and Import

# %%
# %load_ext autoreload
# %autoreload 2
# Preprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc, pickle, warnings

from train import *
from utils import *
warnings.filterwarnings('ignore')

# data
industry = "automobile"
with open(f"data/{industry}/data4model.pickle", "rb") as f:
    data = pickle.load(f)

# preprocess; most preprocess are done in data file, eg. standardise, ...
data = data.reset_index()
data["ymd"] = pd.to_datetime(data["ymd"], format="%Y-%m-%d")
data = data.set_index(["code", "ymd"])

# %% [markdown]
# ### Train

# %% [markdown]
# ##### Build porfolio and rolling prediciton

# %%
models = \
        {
        1: "linear",
        2: "elastic net",
        3: "decision tree", 
        4: "random forest", 
        5: "xgboost", 
        6: "svm",
        7: "neural network",
        8: "ensemble", 
        }

model_config = \
        {
        "industry": "automobile",
        "train_size": 5,    
        "test_size": 1,     
        "test_start": 2021,  

        "long_bound": 80,       
        "short_bound": 20,        
        "ls_decision": ["test", "no running"],
        "n_trials": 20,      
        "tune": True,
        "do_short": True, 
        "input_size": 89   
        }

# %%
for i in models:
    if i < 8:
        model_name = models[7]
        portf = portfolio(model_name, data, **model_config)
        portf.rolling_prediction()
        break
# Out:
# [I 2024-01-11 15:31:41,298] A new study created in memory with name: no-name-3878d178-72c3-4a5d-b8b6-ecfcbf4014c5
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 15:32:12,591] Trial 0 finished with value: -0.004680621437728405 and parameters: {'n_layers': 1, 'active': True, 'hidden_nodes0': 28, 'optimizer': 'SGD', 'lr': 0.033392053514652666, 'epochs': 166, 'reg_coef': 0.0006450874946244092}. Best is trial 0 with value: -0.004680621437728405.
# [I 2024-01-11 15:34:03,596] Trial 1 finished with value: -0.0011519562685862184 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 456, 'hidden_nodes1': 135, 'hidden_nodes2': 273, 'hidden_nodes3': 477, 'hidden_nodes4': 369, 'hidden_nodes5': 278, 'optimizer': 'SGD', 'lr': 0.041331335617116875, 'epochs': 247, 'reg_coef': 0.0003243247045436502}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:35:29,779] Trial 2 finished with value: -0.01987375132739544 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 85, 'hidden_nodes1': 455, 'hidden_nodes2': 176, 'hidden_nodes3': 509, 'hidden_nodes4': 490, 'hidden_nodes5': 303, 'hidden_nodes6': 393, 'optimizer': 'SGD', 'lr': 0.00016382303046151635, 'epochs': 167, 'reg_coef': 2.3554543286501854e-05}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:38:16,597] Trial 3 finished with value: -0.22845402359962463 and parameters: {'n_layers': 10, 'active': True, 'hidden_nodes0': 207, 'hidden_nodes1': 21, 'hidden_nodes2': 471, 'hidden_nodes3': 282, 'hidden_nodes4': 216, 'hidden_nodes5': 437, 'hidden_nodes6': 471, 'hidden_nodes7': 160, 'hidden_nodes8': 54, 'hidden_nodes9': 350, 'optimizer': 'SGD', 'lr': 0.0076444651836794116, 'epochs': 244, 'reg_coef': 0.0047953328266294335}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:39:23,118] Trial 4 finished with value: -0.0158781036734581 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 477, 'hidden_nodes1': 341, 'optimizer': 'RMSprop', 'lr': 0.033933013591629084, 'epochs': 242, 'reg_coef': 3.374236592523473e-05}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:41:26,182] Trial 5 finished with value: -0.12283243238925934 and parameters: {'n_layers': 10, 'active': True, 'hidden_nodes0': 334, 'hidden_nodes1': 497, 'hidden_nodes2': 403, 'hidden_nodes3': 300, 'hidden_nodes4': 199, 'hidden_nodes5': 472, 'hidden_nodes6': 7, 'hidden_nodes7': 219, 'hidden_nodes8': 16, 'hidden_nodes9': 101, 'optimizer': 'RMSprop', 'lr': 1.3252810115689351e-05, 'epochs': 180, 'reg_coef': 0.014121063428889014}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:43:27,822] Trial 6 finished with value: -0.0013617526274174452 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 215, 'hidden_nodes1': 479, 'hidden_nodes2': 223, 'hidden_nodes3': 307, 'hidden_nodes4': 319, 'optimizer': 'SGD', 'lr': 0.0013612813476786582, 'epochs': 300, 'reg_coef': 0.06610802658939273}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:44:38,097] Trial 7 finished with value: -0.004087639041244984 and parameters: {'n_layers': 5, 'active': True, 'hidden_nodes0': 66, 'hidden_nodes1': 162, 'hidden_nodes2': 94, 'hidden_nodes3': 493, 'hidden_nodes4': 247, 'optimizer': 'SGD', 'lr': 0.05209778774475774, 'epochs': 169, 'reg_coef': 0.0013076913804588198}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:45:37,026] Trial 8 finished with value: -0.019673166796565056 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 202, 'hidden_nodes1': 368, 'optimizer': 'SGD', 'lr': 0.03429834548704933, 'epochs': 224, 'reg_coef': 0.0019421728503937064}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:48:01,484] Trial 9 finished with value: -0.0742923840880394 and parameters: {'n_layers': 7, 'active': True, 'hidden_nodes0': 19, 'hidden_nodes1': 11, 'hidden_nodes2': 162, 'hidden_nodes3': 494, 'hidden_nodes4': 478, 'hidden_nodes5': 84, 'hidden_nodes6': 312, 'optimizer': 'RMSprop', 'lr': 0.00015326550694828132, 'epochs': 271, 'reg_coef': 0.005962695191976031}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:49:43,413] Trial 10 finished with value: -0.005821462720632553 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 507, 'hidden_nodes1': 187, 'hidden_nodes2': 348, 'hidden_nodes3': 22, 'hidden_nodes4': 83, 'hidden_nodes5': 184, 'hidden_nodes6': 93, 'optimizer': 'Adam', 'lr': 0.0036511982644388996, 'epochs': 206, 'reg_coef': 0.00019800454109799906}. Best is trial 1 with value: -0.0011519562685862184.
# [I 2024-01-11 15:51:27,746] Trial 11 finished with value: -0.0003498923033475876 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 341, 'hidden_nodes1': 143, 'hidden_nodes2': 266, 'hidden_nodes3': 375, 'optimizer': 'Adam', 'lr': 0.0007810123933013194, 'epochs': 293, 'reg_coef': 0.08625775053950958}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 15:53:13,439] Trial 12 finished with value: -0.000665185390971601 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 385, 'hidden_nodes1': 136, 'hidden_nodes2': 307, 'hidden_nodes3': 387, 'optimizer': 'Adam', 'lr': 0.0002059201110970763, 'epochs': 297, 'reg_coef': 0.00020265505708469026}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 15:55:02,649] Trial 13 pruned.
# [I 2024-01-11 15:56:30,093] Trial 14 finished with value: -0.008049262687563896 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 375, 'hidden_nodes1': 261, 'hidden_nodes2': 366, 'optimizer': 'Adam', 'lr': 0.00047370891238786273, 'epochs': 281, 'reg_coef': 0.00010843880613629627}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 15:58:14,593] Trial 15 finished with value: -0.006187765393406153 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 298, 'hidden_nodes1': 237, 'hidden_nodes2': 19, 'hidden_nodes3': 153, 'optimizer': 'Adam', 'lr': 2.537559188368001e-05, 'epochs': 271, 'reg_coef': 1.0429313967745573e-05}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 15:59:39,942] Trial 16 finished with value: -0.001415175967849791 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 419, 'hidden_nodes1': 79, 'hidden_nodes2': 493, 'optimizer': 'Adam', 'lr': 0.0006832052884347707, 'epochs': 282, 'reg_coef': 0.017272803166678292}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 16:01:08,532] Trial 17 finished with value: -0.0010310966754332185 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 294, 'hidden_nodes1': 225, 'hidden_nodes2': 230, 'hidden_nodes3': 390, 'optimizer': 'Adam', 'lr': 4.926565938965499e-05, 'epochs': 260, 'reg_coef': 8.916426837482745e-05}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 16:02:59,020] Trial 18 finished with value: -0.004552333615720272 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 407, 'hidden_nodes1': 307, 'hidden_nodes2': 315, 'hidden_nodes3': 382, 'hidden_nodes4': 9, 'hidden_nodes5': 22, 'hidden_nodes6': 186, 'hidden_nodes7': 502, 'optimizer': 'Adam', 'lr': 0.0019760618872726008, 'epochs': 213, 'reg_coef': 0.000579205779783211}. Best is trial 11 with value: -0.0003498923033475876.
# [I 2024-01-11 16:03:50,266] Trial 19 finished with value: -0.009323451668024063 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 261, 'optimizer': 'Adam', 'lr': 0.00035109391783517437, 'epochs': 287, 'reg_coef': 0.020027523705861992}. Best is trial 11 with value: -0.0003498923033475876.
# {'n_layers': 4, 'active': False, 'hidden_nodes0': 341, 'hidden_nodes1': 143, 'hidden_nodes2': 266, 'hidden_nodes3': 375, 'optimizer': 'Adam', 'lr': 0.0007810123933013194, 'epochs': 293, 'reg_coef': 0.08625775053950958}
# ===> training start
# [I 2024-01-11 16:03:59,227] A new study created in memory with name: no-name-a24baeaf-ef1c-4c8d-9e43-82fd3e504224
# 2021-02-01 00:00:00
#    performance        ymd
# 0     0.054878 2021-01-11
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 16:04:31,785] Trial 0 finished with value: -0.0034394285175949335 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 90, 'optimizer': 'RMSprop', 'lr': 0.0005958122690979596, 'epochs': 182, 'reg_coef': 0.00016845713096704968}. Best is trial 0 with value: -0.0034394285175949335.
# [I 2024-01-11 16:05:28,609] Trial 1 finished with value: -0.05855599418282509 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 474, 'hidden_nodes1': 381, 'optimizer': 'SGD', 'lr': 0.0008353725356752392, 'epochs': 211, 'reg_coef': 0.00041748821976906686}. Best is trial 0 with value: -0.0034394285175949335.
# [I 2024-01-11 16:06:01,614] Trial 2 finished with value: -0.0027389207389205694 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 185, 'optimizer': 'Adam', 'lr': 0.001520778979199442, 'epochs': 183, 'reg_coef': 0.000135732414217032}. Best is trial 2 with value: -0.0027389207389205694.
# [I 2024-01-11 16:07:16,185] Trial 3 finished with value: -0.12572741508483887 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 443, 'hidden_nodes1': 49, 'optimizer': 'SGD', 'lr': 1.9656023647161496e-05, 'epochs': 279, 'reg_coef': 0.0012750188393323178}. Best is trial 2 with value: -0.0027389207389205694.
# [I 2024-01-11 16:08:30,479] Trial 4 finished with value: -0.00155048503074795 and parameters: {'n_layers': 2, 'active': False, 'hidden_nodes0': 159, 'hidden_nodes1': 410, 'optimizer': 'Adam', 'lr': 0.0006718547891738369, 'epochs': 290, 'reg_coef': 2.487841762028014e-05}. Best is trial 4 with value: -0.00155048503074795.
# [I 2024-01-11 16:09:17,771] Trial 5 finished with value: -0.027742167934775352 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 350, 'hidden_nodes1': 69, 'optimizer': 'Adam', 'lr': 0.007449875288549086, 'epochs': 181, 'reg_coef': 0.006001069540632717}. Best is trial 4 with value: -0.00155048503074795.
# [I 2024-01-11 16:10:07,969] Trial 6 finished with value: -0.004150922875851393 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 369, 'optimizer': 'SGD', 'lr': 0.0007614950016673464, 'epochs': 281, 'reg_coef': 0.00615313556311922}. Best is trial 4 with value: -0.00155048503074795.
# [I 2024-01-11 16:11:37,279] Trial 7 finished with value: -0.0007120510563254356 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 490, 'hidden_nodes1': 346, 'hidden_nodes2': 473, 'hidden_nodes3': 22, 'optimizer': 'RMSprop', 'lr': 1.2364351631394884e-05, 'epochs': 248, 'reg_coef': 0.0010871684347670797}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:13:17,569] Trial 8 finished with value: -0.020441006869077682 and parameters: {'n_layers': 8, 'active': True, 'hidden_nodes0': 449, 'hidden_nodes1': 137, 'hidden_nodes2': 38, 'hidden_nodes3': 299, 'hidden_nodes4': 255, 'hidden_nodes5': 327, 'hidden_nodes6': 37, 'hidden_nodes7': 316, 'optimizer': 'Adam', 'lr': 1.809900034951715e-05, 'epochs': 179, 'reg_coef': 0.02926222691447169}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:15:42,035] Trial 9 finished with value: -0.00570013327524066 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 348, 'hidden_nodes1': 157, 'hidden_nodes2': 42, 'hidden_nodes3': 347, 'hidden_nodes4': 171, 'hidden_nodes5': 186, 'hidden_nodes6': 110, 'hidden_nodes7': 134, 'optimizer': 'Adam', 'lr': 0.0032130944853028063, 'epochs': 276, 'reg_coef': 0.08251189483442727}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:17:16,447] Trial 10 finished with value: -0.013085656799376011 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 279, 'hidden_nodes1': 277, 'hidden_nodes2': 508, 'hidden_nodes3': 11, 'hidden_nodes4': 490, 'optimizer': 'RMSprop', 'lr': 0.09958216698020882, 'epochs': 241, 'reg_coef': 2.5648453509789593e-05}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:18:52,960] Trial 11 pruned.
# [I 2024-01-11 16:20:37,418] Trial 12 finished with value: -0.00531796645373106 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 178, 'hidden_nodes1': 386, 'hidden_nodes2': 315, 'hidden_nodes3': 161, 'optimizer': 'RMSprop', 'lr': 0.00010575640370022294, 'epochs': 300, 'reg_coef': 0.0018162395535914148}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:23:27,881] Trial 13 finished with value: -0.01181555725634098 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 7, 'hidden_nodes1': 380, 'hidden_nodes2': 316, 'hidden_nodes3': 489, 'hidden_nodes4': 482, 'hidden_nodes5': 510, 'hidden_nodes6': 463, 'hidden_nodes7': 460, 'hidden_nodes8': 399, 'hidden_nodes9': 334, 'optimizer': 'Adam', 'lr': 0.02349886129953482, 'epochs': 253, 'reg_coef': 6.603764402155754e-05}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:24:46,162] Trial 14 finished with value: -0.005881112534552813 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 185, 'hidden_nodes1': 500, 'hidden_nodes2': 188, 'hidden_nodes3': 154, 'optimizer': 'RMSprop', 'lr': 0.0001055231460344177, 'epochs': 216, 'reg_coef': 0.00042868894643870094}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:26:20,656] Trial 15 pruned.
# [I 2024-01-11 16:28:03,659] Trial 16 finished with value: -0.0034625865519046783 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 123, 'hidden_nodes1': 427, 'hidden_nodes2': 190, 'hidden_nodes3': 157, 'hidden_nodes4': 18, 'hidden_nodes5': 16, 'optimizer': 'RMSprop', 'lr': 0.00025021126913909135, 'epochs': 233, 'reg_coef': 3.7469595637636554e-05}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:30:14,905] Trial 17 finished with value: -0.0016192331677302718 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 505, 'hidden_nodes1': 319, 'hidden_nodes2': 404, 'hidden_nodes3': 429, 'hidden_nodes4': 329, 'hidden_nodes5': 511, 'hidden_nodes6': 458, 'optimizer': 'RMSprop', 'lr': 4.292187037885147e-05, 'epochs': 269, 'reg_coef': 1.0292647965702728e-05}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:31:37,289] Trial 18 finished with value: -0.022807421162724495 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 262, 'hidden_nodes1': 204, 'hidden_nodes2': 407, 'optimizer': 'Adam', 'lr': 0.012788460424828368, 'epochs': 260, 'reg_coef': 0.0003470119134331213}. Best is trial 7 with value: -0.0007120510563254356.
# [I 2024-01-11 16:32:32,029] Trial 19 finished with value: -0.0013032470596954226 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 398, 'hidden_nodes1': 428, 'hidden_nodes2': 164, 'hidden_nodes3': 93, 'optimizer': 'SGD', 'lr': 0.000280452640308861, 'epochs': 156, 'reg_coef': 0.0022351318729487307}. Best is trial 7 with value: -0.0007120510563254356.
# {'n_layers': 4, 'active': False, 'hidden_nodes0': 490, 'hidden_nodes1': 346, 'hidden_nodes2': 473, 'hidden_nodes3': 22, 'optimizer': 'RMSprop', 'lr': 1.2364351631394884e-05, 'epochs': 248, 'reg_coef': 0.0010871684347670797}
# ===> training start
# [I 2024-01-11 16:32:32,956] A new study created in memory with name: no-name-98d304e9-9170-4f02-a63c-981a81cfaf9c
# 2021-03-01 00:00:00
#    performance        ymd
# 0     0.021783 2021-02-09
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 16:34:55,495] Trial 0 finished with value: -0.0797858014702797 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 185, 'hidden_nodes1': 41, 'hidden_nodes2': 133, 'hidden_nodes3': 127, 'hidden_nodes4': 232, 'hidden_nodes5': 453, 'hidden_nodes6': 366, 'hidden_nodes7': 92, 'hidden_nodes8': 50, 'optimizer': 'Adam', 'lr': 1.585553029325435e-05, 'epochs': 235, 'reg_coef': 9.766922785765222e-05}. Best is trial 0 with value: -0.0797858014702797.
# [I 2024-01-11 16:35:57,906] Trial 1 finished with value: -0.004681100603193045 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 375, 'hidden_nodes1': 38, 'optimizer': 'Adam', 'lr': 0.0033040358486831818, 'epochs': 234, 'reg_coef': 0.009032539940117958}. Best is trial 1 with value: -0.004681100603193045.
# [I 2024-01-11 16:37:07,484] Trial 2 finished with value: -0.00277590355835855 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 80, 'hidden_nodes1': 351, 'hidden_nodes2': 345, 'optimizer': 'Adam', 'lr': 0.002602109339907158, 'epochs': 228, 'reg_coef': 3.696160637304667e-05}. Best is trial 2 with value: -0.00277590355835855.
# [I 2024-01-11 16:38:48,300] Trial 3 finished with value: -0.008523701690137386 and parameters: {'n_layers': 5, 'active': True, 'hidden_nodes0': 327, 'hidden_nodes1': 488, 'hidden_nodes2': 91, 'hidden_nodes3': 116, 'hidden_nodes4': 439, 'optimizer': 'SGD', 'lr': 0.027164246635544197, 'epochs': 244, 'reg_coef': 0.009702936419166756}. Best is trial 2 with value: -0.00277590355835855.
# [I 2024-01-11 16:39:52,948] Trial 4 finished with value: -0.004911231342703104 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 257, 'hidden_nodes1': 145, 'hidden_nodes2': 103, 'optimizer': 'SGD', 'lr': 7.537123230418726e-05, 'epochs': 193, 'reg_coef': 0.09293042939841253}. Best is trial 2 with value: -0.00277590355835855.
# [I 2024-01-11 16:41:07,097] Trial 5 finished with value: -0.0005084117292426527 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 297, 'hidden_nodes1': 290, 'hidden_nodes2': 108, 'optimizer': 'RMSprop', 'lr': 6.812785582347104e-05, 'epochs': 245, 'reg_coef': 2.0439377763906912e-05}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:42:28,870] Trial 6 finished with value: -0.006335848476737738 and parameters: {'n_layers': 4, 'active': True, 'hidden_nodes0': 323, 'hidden_nodes1': 342, 'hidden_nodes2': 314, 'hidden_nodes3': 107, 'optimizer': 'SGD', 'lr': 2.1048998166886845e-05, 'epochs': 223, 'reg_coef': 0.009718582061456094}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:43:58,903] Trial 7 finished with value: -0.04805641993880272 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 182, 'hidden_nodes1': 340, 'hidden_nodes2': 483, 'hidden_nodes3': 21, 'hidden_nodes4': 120, 'optimizer': 'SGD', 'lr': 2.3593154957565987e-05, 'epochs': 230, 'reg_coef': 0.009227825335425722}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:45:27,932] Trial 8 finished with value: -0.006097684148699045 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 200, 'hidden_nodes1': 295, 'hidden_nodes2': 436, 'hidden_nodes3': 411, 'optimizer': 'RMSprop', 'lr': 0.05302865386471714, 'epochs': 257, 'reg_coef': 0.004515699893641388}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:47:39,463] Trial 9 finished with value: -0.02531859278678894 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 475, 'hidden_nodes1': 39, 'hidden_nodes2': 469, 'hidden_nodes3': 201, 'hidden_nodes4': 193, 'hidden_nodes5': 115, 'hidden_nodes6': 175, 'hidden_nodes7': 357, 'hidden_nodes8': 329, 'optimizer': 'SGD', 'lr': 0.0029957267100729256, 'epochs': 226, 'reg_coef': 0.014097307965932435}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:48:31,627] Trial 10 finished with value: -0.13757957518100739 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 512, 'optimizer': 'RMSprop', 'lr': 0.00020118697560160475, 'epochs': 292, 'reg_coef': 1.2746814904476724e-05}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:49:56,491] Trial 11 finished with value: -0.040117014199495316 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 8, 'hidden_nodes1': 447, 'hidden_nodes2': 257, 'hidden_nodes3': 507, 'hidden_nodes4': 506, 'hidden_nodes5': 11, 'hidden_nodes6': 509, 'optimizer': 'Adam', 'lr': 0.0005366323046492427, 'epochs': 180, 'reg_coef': 7.068635243690267e-05}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:50:47,102] Trial 12 finished with value: -0.032605770975351334 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 39, 'optimizer': 'RMSprop', 'lr': 0.002531604876535163, 'epochs': 285, 'reg_coef': 1.5230010845895977e-05}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:51:58,044] Trial 13 finished with value: -0.0016504914965480566 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 80, 'hidden_nodes1': 217, 'hidden_nodes2': 10, 'hidden_nodes3': 350, 'hidden_nodes4': 16, 'hidden_nodes5': 487, 'hidden_nodes6': 13, 'optimizer': 'RMSprop', 'lr': 0.011645621796664375, 'epochs': 153, 'reg_coef': 0.0002039235233040123}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:53:13,964] Trial 14 finished with value: -0.004488030448555946 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 113, 'hidden_nodes1': 189, 'hidden_nodes2': 10, 'hidden_nodes3': 316, 'hidden_nodes4': 4, 'hidden_nodes5': 511, 'hidden_nodes6': 9, 'optimizer': 'RMSprop', 'lr': 0.014501823699348836, 'epochs': 162, 'reg_coef': 0.00044952063742943944}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:54:49,777] Trial 15 finished with value: -0.0035246589686721563 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 412, 'hidden_nodes1': 204, 'hidden_nodes2': 7, 'hidden_nodes3': 312, 'hidden_nodes4': 12, 'hidden_nodes5': 292, 'hidden_nodes6': 12, 'optimizer': 'RMSprop', 'lr': 0.010675014919098726, 'epochs': 202, 'reg_coef': 0.0003651841378111494}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:57:33,124] Trial 16 finished with value: -0.012584466487169266 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 293, 'hidden_nodes1': 235, 'hidden_nodes2': 195, 'hidden_nodes3': 422, 'hidden_nodes4': 348, 'hidden_nodes5': 344, 'hidden_nodes6': 206, 'hidden_nodes7': 506, 'hidden_nodes8': 490, 'hidden_nodes9': 512, 'optimizer': 'RMSprop', 'lr': 0.00030279000139297893, 'epochs': 268, 'reg_coef': 0.00020138490365021939}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 16:58:38,806] Trial 17 finished with value: -0.003953925333917141 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 134, 'hidden_nodes1': 100, 'hidden_nodes2': 62, 'hidden_nodes3': 254, 'hidden_nodes4': 116, 'hidden_nodes5': 391, 'optimizer': 'RMSprop', 'lr': 9.208889055305154e-05, 'epochs': 151, 'reg_coef': 0.001282792376270435}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 17:00:27,066] Trial 18 finished with value: -0.0032980679534375668 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 246, 'hidden_nodes1': 399, 'hidden_nodes2': 156, 'hidden_nodes3': 387, 'hidden_nodes4': 313, 'hidden_nodes5': 182, 'hidden_nodes6': 118, 'hidden_nodes7': 21, 'optimizer': 'RMSprop', 'lr': 0.0867067338527847, 'epochs': 208, 'reg_coef': 3.301867424592881e-05}. Best is trial 5 with value: -0.0005084117292426527.
# [I 2024-01-11 17:01:44,644] Trial 19 finished with value: -0.013406376354396343 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 389, 'hidden_nodes1': 276, 'hidden_nodes2': 209, 'hidden_nodes3': 499, 'hidden_nodes4': 109, 'hidden_nodes5': 217, 'optimizer': 'RMSprop', 'lr': 0.0010271303439587634, 'epochs': 178, 'reg_coef': 0.0018005150239650057}. Best is trial 5 with value: -0.0005084117292426527.
# {'n_layers': 3, 'active': False, 'hidden_nodes0': 297, 'hidden_nodes1': 290, 'hidden_nodes2': 108, 'optimizer': 'RMSprop', 'lr': 6.812785582347104e-05, 'epochs': 245, 'reg_coef': 2.0439377763906912e-05}
# ===> training start
# [I 2024-01-11 17:01:48,447] A new study created in memory with name: no-name-351103e3-11ac-4269-924a-bac926e2be0f
# 2021-04-01 00:00:00
#    performance        ymd
# 0     0.022486 2021-03-10
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 17:03:13,359] Trial 0 finished with value: -0.0021389892790466547 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 51, 'hidden_nodes1': 363, 'hidden_nodes2': 379, 'hidden_nodes3': 393, 'hidden_nodes4': 245, 'hidden_nodes5': 101, 'hidden_nodes6': 34, 'optimizer': 'Adam', 'lr': 1.5171401822377312e-05, 'epochs': 178, 'reg_coef': 0.09174513769400677}. Best is trial 0 with value: -0.0021389892790466547.
# [I 2024-01-11 17:04:47,910] Trial 1 finished with value: -0.28569263219833374 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 144, 'hidden_nodes1': 180, 'hidden_nodes2': 218, 'hidden_nodes3': 185, 'hidden_nodes4': 490, 'hidden_nodes5': 37, 'optimizer': 'SGD', 'lr': 0.04098353357974367, 'epochs': 205, 'reg_coef': 0.00019550697960523818}. Best is trial 0 with value: -0.0021389892790466547.
# [I 2024-01-11 17:06:25,617] Trial 2 finished with value: -0.04554210230708122 and parameters: {'n_layers': 4, 'active': True, 'hidden_nodes0': 364, 'hidden_nodes1': 359, 'hidden_nodes2': 133, 'hidden_nodes3': 442, 'optimizer': 'SGD', 'lr': 0.08442738766979854, 'epochs': 265, 'reg_coef': 0.07704486328077641}. Best is trial 0 with value: -0.0021389892790466547.
# [I 2024-01-11 17:07:18,080] Trial 3 finished with value: -0.0007947584963403642 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 209, 'hidden_nodes1': 132, 'hidden_nodes2': 27, 'optimizer': 'SGD', 'lr': 0.021199724228855552, 'epochs': 170, 'reg_coef': 0.015103918915868316}. Best is trial 3 with value: -0.0007947584963403642.
# [I 2024-01-11 17:08:55,477] Trial 4 finished with value: -0.07089964300394058 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 475, 'hidden_nodes1': 399, 'hidden_nodes2': 461, 'hidden_nodes3': 475, 'hidden_nodes4': 53, 'hidden_nodes5': 171, 'hidden_nodes6': 150, 'hidden_nodes7': 157, 'hidden_nodes8': 33, 'optimizer': 'Adam', 'lr': 1.3845818885715226e-05, 'epochs': 163, 'reg_coef': 2.9393576447453384e-05}. Best is trial 3 with value: -0.0007947584963403642.
# [I 2024-01-11 17:09:52,475] Trial 5 finished with value: -0.014388974756002426 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 394, 'hidden_nodes1': 186, 'optimizer': 'SGD', 'lr': 0.00012808357698334725, 'epochs': 210, 'reg_coef': 0.0006092782428049035}. Best is trial 3 with value: -0.0007947584963403642.
# [I 2024-01-11 17:10:51,991] Trial 6 finished with value: -0.0005559211131185293 and parameters: {'n_layers': 2, 'active': False, 'hidden_nodes0': 84, 'hidden_nodes1': 304, 'optimizer': 'SGD', 'lr': 0.00010603116120566912, 'epochs': 229, 'reg_coef': 0.0011015157560869853}. Best is trial 6 with value: -0.0005559211131185293.
# [I 2024-01-11 17:12:34,001] Trial 7 finished with value: -0.0795140415430069 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 280, 'hidden_nodes1': 478, 'hidden_nodes2': 448, 'hidden_nodes3': 379, 'hidden_nodes4': 30, 'hidden_nodes5': 198, 'optimizer': 'RMSprop', 'lr': 0.005513157933539835, 'epochs': 219, 'reg_coef': 0.011060924389034157}. Best is trial 6 with value: -0.0005559211131185293.
# [I 2024-01-11 17:13:55,114] Trial 8 finished with value: -0.03123805671930313 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 402, 'hidden_nodes1': 141, 'hidden_nodes2': 454, 'optimizer': 'RMSprop', 'lr': 1.3865189609299946e-05, 'epochs': 254, 'reg_coef': 0.0005764161836233969}. Best is trial 6 with value: -0.0005559211131185293.
# [I 2024-01-11 17:15:49,215] Trial 9 pruned.
# [I 2024-01-11 17:16:43,014] Trial 10 finished with value: -0.0012136278674006462 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 64, 'optimizer': 'SGD', 'lr': 0.00035263178231157626, 'epochs': 300, 'reg_coef': 2.0354248551902217e-05}. Best is trial 6 with value: -0.0005559211131185293.
# [I 2024-01-11 17:17:58,163] Trial 11 finished with value: -0.0005260839243419468 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 173, 'hidden_nodes1': 50, 'hidden_nodes2': 35, 'optimizer': 'SGD', 'lr': 0.004979424015634084, 'epochs': 244, 'reg_coef': 0.0038480417912327984}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:18:43,972] Trial 12 finished with value: -0.0010923325316980481 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 145, 'optimizer': 'SGD', 'lr': 0.0025275705020518166, 'epochs': 249, 'reg_coef': 0.00216897599020683}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:20:06,719] Trial 13 finished with value: -0.0006987572414800525 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 141, 'hidden_nodes1': 29, 'hidden_nodes2': 4, 'hidden_nodes3': 19, 'optimizer': 'SGD', 'lr': 0.0001386926935219948, 'epochs': 237, 'reg_coef': 0.0032130678489684884}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:21:46,733] Trial 14 finished with value: -0.010693082585930824 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 5, 'hidden_nodes1': 260, 'hidden_nodes2': 133, 'hidden_nodes3': 289, 'optimizer': 'SGD', 'lr': 0.0007448540340125676, 'epochs': 285, 'reg_coef': 0.00015675536511276404}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:22:48,368] Trial 15 finished with value: -0.0010993514442816377 and parameters: {'n_layers': 2, 'active': False, 'hidden_nodes0': 211, 'hidden_nodes1': 44, 'optimizer': 'Adam', 'lr': 0.0053953276514020565, 'epochs': 232, 'reg_coef': 0.004099664265360566}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:23:50,894] Trial 16 finished with value: -0.0014527438906952739 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 76, 'hidden_nodes1': 508, 'hidden_nodes2': 319, 'optimizer': 'SGD', 'lr': 6.655538404275508e-05, 'epochs': 201, 'reg_coef': 0.00011701255203915622}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:25:40,388] Trial 17 finished with value: -0.001546557992696762 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 205, 'hidden_nodes1': 243, 'hidden_nodes2': 114, 'hidden_nodes3': 4, 'hidden_nodes4': 413, 'optimizer': 'SGD', 'lr': 0.0005721977109991898, 'epochs': 279, 'reg_coef': 0.0012665546126823166}. Best is trial 11 with value: -0.0005260839243419468.
# [I 2024-01-11 17:26:43,294] Trial 18 pruned.
# [I 2024-01-11 17:28:14,367] Trial 19 finished with value: -0.002932483097538352 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 106, 'hidden_nodes1': 243, 'hidden_nodes2': 235, 'hidden_nodes3': 286, 'hidden_nodes4': 253, 'hidden_nodes5': 473, 'hidden_nodes6': 466, 'optimizer': 'RMSprop', 'lr': 0.012261451664469824, 'epochs': 191, 'reg_coef': 0.00038477733620378377}. Best is trial 11 with value: -0.0005260839243419468.
# {'n_layers': 3, 'active': False, 'hidden_nodes0': 173, 'hidden_nodes1': 50, 'hidden_nodes2': 35, 'optimizer': 'SGD', 'lr': 0.004979424015634084, 'epochs': 244, 'reg_coef': 0.0038480417912327984}
# ===> training start
# [I 2024-01-11 17:28:25,186] A new study created in memory with name: no-name-6edefbbc-38bb-4d79-bfff-f9ebf4780e1d
# 2021-05-01 00:00:00
#    performance        ymd
# 0    -0.031732 2021-04-12
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 17:30:27,640] Trial 0 finished with value: -0.017008794471621513 and parameters: {'n_layers': 7, 'active': True, 'hidden_nodes0': 472, 'hidden_nodes1': 353, 'hidden_nodes2': 457, 'hidden_nodes3': 352, 'hidden_nodes4': 74, 'hidden_nodes5': 257, 'hidden_nodes6': 12, 'optimizer': 'RMSprop', 'lr': 0.002866377427411738, 'epochs': 240, 'reg_coef': 1.368746622033834e-05}. Best is trial 0 with value: -0.017008794471621513.
# [I 2024-01-11 17:33:12,334] Trial 1 finished with value: -0.012329314835369587 and parameters: {'n_layers': 9, 'active': False, 'hidden_nodes0': 421, 'hidden_nodes1': 371, 'hidden_nodes2': 479, 'hidden_nodes3': 465, 'hidden_nodes4': 161, 'hidden_nodes5': 163, 'hidden_nodes6': 279, 'hidden_nodes7': 351, 'hidden_nodes8': 438, 'optimizer': 'Adam', 'lr': 0.02046796883419928, 'epochs': 286, 'reg_coef': 0.0003070334085708404}. Best is trial 1 with value: -0.012329314835369587.
# [I 2024-01-11 17:34:40,029] Trial 2 finished with value: -0.028240656480193138 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 329, 'hidden_nodes1': 124, 'hidden_nodes2': 138, 'optimizer': 'RMSprop', 'lr': 0.00024055015712948612, 'epochs': 277, 'reg_coef': 0.005938329778912741}. Best is trial 1 with value: -0.012329314835369587.
# [I 2024-01-11 17:37:20,998] Trial 3 finished with value: -0.005172016564756632 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 119, 'hidden_nodes1': 391, 'hidden_nodes2': 39, 'hidden_nodes3': 217, 'hidden_nodes4': 447, 'hidden_nodes5': 314, 'hidden_nodes6': 321, 'hidden_nodes7': 286, 'hidden_nodes8': 245, 'hidden_nodes9': 198, 'optimizer': 'Adam', 'lr': 0.007456514085357855, 'epochs': 263, 'reg_coef': 0.00010312550780157759}. Best is trial 3 with value: -0.005172016564756632.
# [I 2024-01-11 17:37:51,603] Trial 4 finished with value: -0.025192558765411377 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 199, 'optimizer': 'Adam', 'lr': 5.255150844010301e-05, 'epochs': 164, 'reg_coef': 0.0017205968106174276}. Best is trial 3 with value: -0.005172016564756632.
# [I 2024-01-11 17:38:42,018] Trial 5 finished with value: -0.0005748285911977291 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 472, 'optimizer': 'Adam', 'lr': 0.037754030970479295, 'epochs': 276, 'reg_coef': 3.513756190732753e-05}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:41:18,565] Trial 6 finished with value: -0.002198887523263693 and parameters: {'n_layers': 9, 'active': False, 'hidden_nodes0': 323, 'hidden_nodes1': 329, 'hidden_nodes2': 84, 'hidden_nodes3': 366, 'hidden_nodes4': 280, 'hidden_nodes5': 72, 'hidden_nodes6': 125, 'hidden_nodes7': 326, 'hidden_nodes8': 123, 'optimizer': 'Adam', 'lr': 0.001149784474601435, 'epochs': 270, 'reg_coef': 0.009506867156397666}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:42:31,907] Trial 7 finished with value: -0.005496852099895477 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 333, 'hidden_nodes1': 26, 'hidden_nodes2': 346, 'hidden_nodes3': 156, 'hidden_nodes4': 379, 'hidden_nodes5': 177, 'optimizer': 'Adam', 'lr': 7.258873123010769e-05, 'epochs': 160, 'reg_coef': 0.0019952504689199554}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:44:08,986] Trial 8 finished with value: -0.021070808172225952 and parameters: {'n_layers': 8, 'active': True, 'hidden_nodes0': 179, 'hidden_nodes1': 234, 'hidden_nodes2': 336, 'hidden_nodes3': 283, 'hidden_nodes4': 55, 'hidden_nodes5': 249, 'hidden_nodes6': 247, 'hidden_nodes7': 68, 'optimizer': 'SGD', 'lr': 0.013105526089406176, 'epochs': 175, 'reg_coef': 0.021731435269461787}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:45:10,447] Trial 9 finished with value: -0.0070464941672980785 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 425, 'hidden_nodes1': 481, 'hidden_nodes2': 311, 'hidden_nodes3': 172, 'optimizer': 'SGD', 'lr': 0.0021923577846619086, 'epochs': 174, 'reg_coef': 0.00011172443308079164}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:45:49,487] Trial 10 finished with value: -0.006140664219856262 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 508, 'optimizer': 'RMSprop', 'lr': 0.09059947033831638, 'epochs': 213, 'reg_coef': 1.0665874464134098e-05}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:47:34,019] Trial 11 finished with value: -0.027669858187437057 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 328, 'hidden_nodes1': 248, 'hidden_nodes2': 156, 'hidden_nodes3': 8, 'optimizer': 'Adam', 'lr': 0.00046502028728123305, 'epochs': 298, 'reg_coef': 0.07325314623153467}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:49:25,762] Trial 12 finished with value: -0.004116435535252094 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 7, 'hidden_nodes1': 511, 'hidden_nodes2': 17, 'hidden_nodes3': 507, 'hidden_nodes4': 294, 'hidden_nodes5': 13, 'optimizer': 'Adam', 'lr': 1.33642316838191e-05, 'epochs': 252, 'reg_coef': 0.010093691918948738}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:51:37,315] Trial 13 finished with value: -0.0024187739472836256 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 394, 'hidden_nodes1': 163, 'hidden_nodes2': 203, 'hidden_nodes3': 382, 'hidden_nodes4': 245, 'hidden_nodes5': 482, 'hidden_nodes6': 48, 'hidden_nodes7': 500, 'hidden_nodes8': 42, 'hidden_nodes9': 511, 'optimizer': 'Adam', 'lr': 0.07020027935100341, 'epochs': 216, 'reg_coef': 0.00040737141417189693}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:52:48,854] Trial 14 finished with value: -0.09292113780975342 and parameters: {'n_layers': 3, 'active': False, 'hidden_nodes0': 252, 'hidden_nodes1': 302, 'hidden_nodes2': 100, 'optimizer': 'Adam', 'lr': 0.001212092183010687, 'epochs': 233, 'reg_coef': 5.685237515513658e-05}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:55:09,495] Trial 15 finished with value: -0.0006883700261823833 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 373, 'hidden_nodes1': 423, 'hidden_nodes2': 227, 'hidden_nodes3': 65, 'hidden_nodes4': 282, 'hidden_nodes5': 7, 'hidden_nodes6': 152, 'hidden_nodes7': 103, 'optimizer': 'SGD', 'lr': 0.005518000947365645, 'epochs': 268, 'reg_coef': 0.0901408022681758}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:57:34,112] Trial 16 finished with value: -0.0018807410961017013 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 508, 'hidden_nodes1': 442, 'hidden_nodes2': 272, 'hidden_nodes3': 15, 'hidden_nodes4': 512, 'hidden_nodes5': 416, 'hidden_nodes6': 505, 'optimizer': 'SGD', 'lr': 0.04352479662679106, 'epochs': 299, 'reg_coef': 3.797057275115965e-05}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 17:58:53,209] Trial 17 finished with value: -0.005082273855805397 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 385, 'hidden_nodes1': 429, 'hidden_nodes2': 397, 'hidden_nodes3': 90, 'hidden_nodes4': 168, 'optimizer': 'SGD', 'lr': 0.006057506503956107, 'epochs': 199, 'reg_coef': 0.08956205536505701}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 18:00:00,204] Trial 18 finished with value: -0.007220597006380558 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 452, 'hidden_nodes1': 37, 'optimizer': 'SGD', 'lr': 0.02396303139090011, 'epochs': 248, 'reg_coef': 0.0005715171781720783}. Best is trial 5 with value: -0.0005748285911977291.
# [I 2024-01-11 18:02:26,234] Trial 19 finished with value: -0.006498606875538826 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 265, 'hidden_nodes1': 158, 'hidden_nodes2': 194, 'hidden_nodes3': 90, 'hidden_nodes4': 365, 'hidden_nodes5': 102, 'hidden_nodes6': 161, 'hidden_nodes7': 50, 'optimizer': 'SGD', 'lr': 0.004875289483312666, 'epochs': 262, 'reg_coef': 0.002926306399759689}. Best is trial 5 with value: -0.0005748285911977291.
# {'n_layers': 1, 'active': False, 'hidden_nodes0': 472, 'optimizer': 'Adam', 'lr': 0.037754030970479295, 'epochs': 276, 'reg_coef': 3.513756190732753e-05}
# ===> training start
# [I 2024-01-11 18:02:34,544] A new study created in memory with name: no-name-c2d86c3b-45d4-4967-8735-4f4bd8be0fed
# 2021-06-01 00:00:00
#    performance        ymd
# 0    -0.030624 2021-05-10
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 18:03:24,759] Trial 0 finished with value: -0.005203374195843935 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 369, 'optimizer': 'SGD', 'lr': 1.1362488501242132e-05, 'epochs': 250, 'reg_coef': 0.008230588736865396}. Best is trial 0 with value: -0.005203374195843935.
# [I 2024-01-11 18:05:58,919] Trial 1 finished with value: -0.00693142507225275 and parameters: {'n_layers': 10, 'active': True, 'hidden_nodes0': 23, 'hidden_nodes1': 230, 'hidden_nodes2': 47, 'hidden_nodes3': 412, 'hidden_nodes4': 322, 'hidden_nodes5': 94, 'hidden_nodes6': 72, 'hidden_nodes7': 146, 'hidden_nodes8': 445, 'hidden_nodes9': 182, 'optimizer': 'SGD', 'lr': 0.0003936939744877506, 'epochs': 225, 'reg_coef': 0.013895489666580545}. Best is trial 0 with value: -0.005203374195843935.
# [I 2024-01-11 18:07:45,882] Trial 2 finished with value: -0.001317041926085949 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 84, 'hidden_nodes1': 496, 'hidden_nodes2': 451, 'hidden_nodes3': 194, 'hidden_nodes4': 209, 'hidden_nodes5': 57, 'hidden_nodes6': 399, 'optimizer': 'Adam', 'lr': 5.968844933284684e-05, 'epochs': 221, 'reg_coef': 0.00011150316264855752}. Best is trial 2 with value: -0.001317041926085949.
# [I 2024-01-11 18:09:56,785] Trial 3 finished with value: -0.0122175058349967 and parameters: {'n_layers': 8, 'active': True, 'hidden_nodes0': 172, 'hidden_nodes1': 491, 'hidden_nodes2': 175, 'hidden_nodes3': 327, 'hidden_nodes4': 400, 'hidden_nodes5': 132, 'hidden_nodes6': 200, 'hidden_nodes7': 75, 'optimizer': 'RMSprop', 'lr': 0.0026429731294697997, 'epochs': 218, 'reg_coef': 5.307153844313114e-05}. Best is trial 2 with value: -0.001317041926085949.
# [I 2024-01-11 18:11:11,438] Trial 4 finished with value: -0.0005886707804165781 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 308, 'hidden_nodes1': 96, 'hidden_nodes2': 302, 'hidden_nodes3': 211, 'hidden_nodes4': 488, 'optimizer': 'RMSprop', 'lr': 0.006476054542031457, 'epochs': 180, 'reg_coef': 0.002981100746522125}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:13:16,414] Trial 5 finished with value: -0.12132135778665543 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 148, 'hidden_nodes1': 303, 'hidden_nodes2': 137, 'hidden_nodes3': 154, 'hidden_nodes4': 170, 'hidden_nodes5': 457, 'hidden_nodes6': 363, 'hidden_nodes7': 79, 'hidden_nodes8': 178, 'optimizer': 'SGD', 'lr': 0.059462875899139456, 'epochs': 203, 'reg_coef': 6.223790797852801e-05}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:15:32,393] Trial 6 finished with value: -0.250969797372818 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 25, 'hidden_nodes1': 454, 'hidden_nodes2': 249, 'hidden_nodes3': 240, 'hidden_nodes4': 226, 'hidden_nodes5': 95, 'optimizer': 'RMSprop', 'lr': 4.452932420897454e-05, 'epochs': 289, 'reg_coef': 0.07508639607236764}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:16:37,081] Trial 7 finished with value: -0.15195663273334503 and parameters: {'n_layers': 4, 'active': True, 'hidden_nodes0': 131, 'hidden_nodes1': 52, 'hidden_nodes2': 203, 'hidden_nodes3': 4, 'optimizer': 'RMSprop', 'lr': 0.0001654787770632668, 'epochs': 175, 'reg_coef': 0.00830725750973438}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:18:06,485] Trial 8 finished with value: -0.036191344261169434 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 133, 'hidden_nodes1': 297, 'hidden_nodes2': 444, 'optimizer': 'SGD', 'lr': 9.02480765729642e-05, 'epochs': 273, 'reg_coef': 0.09798594829882463}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:19:30,625] Trial 9 pruned.
# [I 2024-01-11 18:19:59,154] Trial 10 finished with value: -0.0047125923447310925 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 476, 'optimizer': 'Adam', 'lr': 0.007533619987836822, 'epochs': 150, 'reg_coef': 0.0007834959662285927}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:21:29,304] Trial 11 finished with value: -0.00103149248752743 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 342, 'hidden_nodes1': 45, 'hidden_nodes2': 442, 'hidden_nodes3': 197, 'hidden_nodes4': 26, 'hidden_nodes5': 315, 'hidden_nodes6': 506, 'optimizer': 'Adam', 'lr': 0.014173955620346484, 'epochs': 187, 'reg_coef': 0.0005737965057520887}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:22:52,127] Trial 12 finished with value: -0.004019422922283411 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 329, 'hidden_nodes1': 10, 'hidden_nodes2': 350, 'hidden_nodes3': 130, 'hidden_nodes4': 508, 'hidden_nodes5': 341, 'optimizer': 'Adam', 'lr': 0.023627645637110187, 'epochs': 184, 'reg_coef': 0.0006357932993193357}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:23:59,313] Trial 13 finished with value: -0.004908191040158272 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 342, 'hidden_nodes1': 113, 'hidden_nodes2': 349, 'hidden_nodes3': 318, 'hidden_nodes4': 15, 'optimizer': 'Adam', 'lr': 0.0025430013565063874, 'epochs': 169, 'reg_coef': 0.0014908121643689126}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:26:14,715] Trial 14 finished with value: -0.0011549178743734956 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 430, 'hidden_nodes1': 144, 'hidden_nodes2': 509, 'hidden_nodes3': 103, 'hidden_nodes4': 26, 'hidden_nodes5': 282, 'hidden_nodes6': 507, 'hidden_nodes7': 499, 'optimizer': 'RMSprop', 'lr': 0.015274884175893483, 'epochs': 195, 'reg_coef': 0.0002941844055707139}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:27:14,917] Trial 15 pruned.
# [I 2024-01-11 18:29:41,509] Trial 16 finished with value: -0.0008016577921807766 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 293, 'hidden_nodes1': 56, 'hidden_nodes2': 304, 'hidden_nodes3': 491, 'hidden_nodes4': 496, 'hidden_nodes5': 496, 'hidden_nodes6': 492, 'optimizer': 'RMSprop', 'lr': 0.0014921829384469498, 'epochs': 201, 'reg_coef': 0.0027857766453147337}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:32:06,758] Trial 17 finished with value: -0.0017784942174330354 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 297, 'hidden_nodes1': 186, 'hidden_nodes2': 283, 'hidden_nodes3': 508, 'hidden_nodes4': 495, 'optimizer': 'RMSprop', 'lr': 0.0009560548271549093, 'epochs': 247, 'reg_coef': 0.0022319529497468126}. Best is trial 4 with value: -0.0005886707804165781.
# [I 2024-01-11 18:34:35,592] Trial 18 finished with value: -0.0002720231132116169 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 409, 'hidden_nodes1': 107, 'hidden_nodes2': 275, 'hidden_nodes3': 486, 'hidden_nodes4': 412, 'hidden_nodes5': 503, 'hidden_nodes6': 233, 'optimizer': 'RMSprop', 'lr': 0.003725355080381355, 'epochs': 206, 'reg_coef': 0.003185923369213573}. Best is trial 18 with value: -0.0002720231132116169.
# [I 2024-01-11 18:38:24,231] Trial 19 finished with value: -0.0011251331306993961 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 419, 'hidden_nodes1': 346, 'hidden_nodes2': 114, 'hidden_nodes3': 324, 'hidden_nodes4': 396, 'hidden_nodes5': 396, 'hidden_nodes6': 185, 'hidden_nodes7': 396, 'hidden_nodes8': 47, 'hidden_nodes9': 438, 'optimizer': 'RMSprop', 'lr': 0.005098722808066434, 'epochs': 239, 'reg_coef': 0.019813850485026277}. Best is trial 18 with value: -0.0002720231132116169.
# {'n_layers': 7, 'active': False, 'hidden_nodes0': 409, 'hidden_nodes1': 107, 'hidden_nodes2': 275, 'hidden_nodes3': 486, 'hidden_nodes4': 412, 'hidden_nodes5': 503, 'hidden_nodes6': 233, 'optimizer': 'RMSprop', 'lr': 0.003725355080381355, 'epochs': 206, 'reg_coef': 0.003185923369213573}
# ===> training start
# [I 2024-01-11 18:38:49,494] A new study created in memory with name: no-name-6a8ad5f4-768e-4aa2-93bc-839412fd5f70
# 2021-07-01 00:00:00
#    performance        ymd
# 0    -0.021237 2021-06-10
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 18:41:31,129] Trial 0 finished with value: -0.011216698214411736 and parameters: {'n_layers': 5, 'active': True, 'hidden_nodes0': 23, 'hidden_nodes1': 178, 'hidden_nodes2': 173, 'hidden_nodes3': 370, 'hidden_nodes4': 190, 'optimizer': 'RMSprop', 'lr': 5.367302834958142e-05, 'epochs': 248, 'reg_coef': 0.0316584125736853}. Best is trial 0 with value: -0.011216698214411736.
# ...
# [I 2024-01-11 20:30:25,290] Trial 17 finished with value: -0.008422045037150383 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 103, 'hidden_nodes1': 229, 'hidden_nodes2': 293, 'hidden_nodes3': 276, 'hidden_nodes4': 393, 'hidden_nodes5': 185, 'hidden_nodes6': 203, 'hidden_nodes7': 384, 'optimizer': 'RMSprop', 'lr': 1.1309306640107974e-05, 'epochs': 251, 'reg_coef': 0.0035852140001977314}. Best is trial 11 with value: -0.000689018692355603.
# [I 2024-01-11 20:33:28,696] Trial 18 finished with value: -0.006179540418088436 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 230, 'hidden_nodes1': 505, 'hidden_nodes2': 81, 'hidden_nodes3': 397, 'hidden_nodes4': 136, 'hidden_nodes5': 198, 'hidden_nodes6': 353, 'hidden_nodes7': 200, 'hidden_nodes8': 187, 'optimizer': 'SGD', 'lr': 4.9420199635372054e-05, 'epochs': 279, 'reg_coef': 0.009685526645704719}. Best is trial 11 with value: -0.000689018692355603.
# [I 2024-01-11 20:35:45,478] Trial 19 finished with value: -0.0018745476845651865 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 362, 'hidden_nodes1': 370, 'hidden_nodes2': 189, 'hidden_nodes3': 272, 'hidden_nodes4': 292, 'hidden_nodes5': 5, 'hidden_nodes6': 206, 'optimizer': 'Adam', 'lr': 0.005124437365652758, 'epochs': 242, 'reg_coef': 0.07852216028708199}. Best is trial 11 with value: -0.000689018692355603.
# {'n_layers': 8, 'active': False, 'hidden_nodes0': 176, 'hidden_nodes1': 384, 'hidden_nodes2': 144, 'hidden_nodes3': 338, 'hidden_nodes4': 9, 'hidden_nodes5': 162, 'hidden_nodes6': 463, 'hidden_nodes7': 464, 'optimizer': 'RMSprop', 'lr': 0.09444396815880987, 'epochs': 249, 'reg_coef': 0.008064639807498847}
# ===> training start
# [I 2024-01-11 20:36:15,606] A new study created in memory with name: no-name-65935c19-8946-4083-9632-a130c1bd0b0d
# 2021-10-01 00:00:00
#    performance        ymd
# 0    -0.007856 2021-09-10
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 20:37:05,810] Trial 0 finished with value: -0.0054442258551716805 and parameters: {'n_layers': 1, 'active': True, 'hidden_nodes0': 338, 'optimizer': 'RMSprop', 'lr': 1.4601293974494161e-05, 'epochs': 226, 'reg_coef': 0.03377074032661328}. Best is trial 0 with value: -0.0054442258551716805.
# [I 2024-01-11 20:38:24,059] Trial 1 finished with value: -0.144545778632164 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 288, 'hidden_nodes1': 79, 'hidden_nodes2': 44, 'hidden_nodes3': 279, 'hidden_nodes4': 161, 'hidden_nodes5': 338, 'optimizer': 'SGD', 'lr': 0.006038813238223017, 'epochs': 161, 'reg_coef': 0.04683691506204059}. Best is trial 0 with value: -0.0054442258551716805.
# [I 2024-01-11 20:39:49,899] Trial 2 finished with value: -0.0030192292761057615 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 284, 'hidden_nodes1': 479, 'hidden_nodes2': 458, 'optimizer': 'Adam', 'lr': 1.0761154212901921e-05, 'epochs': 256, 'reg_coef': 0.0484535298154434}. Best is trial 2 with value: -0.0030192292761057615.
# [I 2024-01-11 20:42:07,164] Trial 3 finished with value: -0.0006798867252655327 and parameters: {'n_layers': 9, 'active': False, 'hidden_nodes0': 362, 'hidden_nodes1': 327, 'hidden_nodes2': 27, 'hidden_nodes3': 106, 'hidden_nodes4': 160, 'hidden_nodes5': 410, 'hidden_nodes6': 29, 'hidden_nodes7': 270, 'hidden_nodes8': 47, 'optimizer': 'SGD', 'lr': 0.010414330376012897, 'epochs': 224, 'reg_coef': 0.012631112852290311}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:42:50,047] Trial 4 finished with value: -0.002538046333938837 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 175, 'hidden_nodes1': 383, 'optimizer': 'RMSprop', 'lr': 0.004615175959682045, 'epochs': 152, 'reg_coef': 0.0010771321005859985}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:45:38,884] Trial 5 finished with value: -0.03227819874882698 and parameters: {'n_layers': 9, 'active': True, 'hidden_nodes0': 201, 'hidden_nodes1': 145, 'hidden_nodes2': 488, 'hidden_nodes3': 510, 'hidden_nodes4': 240, 'hidden_nodes5': 382, 'hidden_nodes6': 375, 'hidden_nodes7': 155, 'hidden_nodes8': 416, 'optimizer': 'Adam', 'lr': 2.0752315078374734e-05, 'epochs': 268, 'reg_coef': 0.00031365215096956425}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:47:08,163] Trial 6 finished with value: -0.006689777597784996 and parameters: {'n_layers': 4, 'active': False, 'hidden_nodes0': 421, 'hidden_nodes1': 334, 'hidden_nodes2': 270, 'hidden_nodes3': 245, 'optimizer': 'RMSprop', 'lr': 0.04008986617086906, 'epochs': 236, 'reg_coef': 0.00018358207947009788}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:48:41,831] Trial 7 finished with value: -0.00953606702387333 and parameters: {'n_layers': 5, 'active': False, 'hidden_nodes0': 428, 'hidden_nodes1': 138, 'hidden_nodes2': 352, 'hidden_nodes3': 108, 'hidden_nodes4': 482, 'optimizer': 'SGD', 'lr': 0.008634715889952535, 'epochs': 222, 'reg_coef': 0.0226042105437195}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:50:25,908] Trial 8 finished with value: -0.003878938499838114 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 61, 'hidden_nodes1': 493, 'hidden_nodes2': 506, 'hidden_nodes3': 50, 'hidden_nodes4': 372, 'hidden_nodes5': 41, 'hidden_nodes6': 507, 'hidden_nodes7': 84, 'optimizer': 'Adam', 'lr': 0.0004808407696652876, 'epochs': 187, 'reg_coef': 0.0028720519849918975}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:51:48,811] Trial 9 finished with value: -0.003392362967133522 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 89, 'hidden_nodes1': 186, 'hidden_nodes2': 469, 'optimizer': 'RMSprop', 'lr': 5.684260956584382e-05, 'epochs': 246, 'reg_coef': 2.154923968403702e-05}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:54:06,627] Trial 10 finished with value: -0.012094789184629917 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 503, 'hidden_nodes1': 278, 'hidden_nodes2': 6, 'hidden_nodes3': 194, 'hidden_nodes4': 11, 'hidden_nodes5': 476, 'hidden_nodes6': 9, 'hidden_nodes7': 454, 'hidden_nodes8': 6, 'hidden_nodes9': 231, 'optimizer': 'SGD', 'lr': 0.08851183037593334, 'epochs': 198, 'reg_coef': 0.00543714641145026}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:55:18,096] Trial 11 finished with value: -0.002007524250075221 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 169, 'optimizer': 'RMSprop', 'lr': 0.001621656873755722, 'epochs': 298, 'reg_coef': 0.0012322958954840248}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 20:58:15,132] Trial 12 finished with value: -0.01358503382652998 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 156, 'hidden_nodes1': 397, 'hidden_nodes2': 124, 'hidden_nodes3': 14, 'hidden_nodes4': 82, 'hidden_nodes5': 171, 'hidden_nodes6': 42, 'optimizer': 'SGD', 'lr': 0.0006447125556860749, 'epochs': 296, 'reg_coef': 0.006310434409684341}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:01:27,137] Trial 13 finished with value: -0.0014312334824353456 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 11, 'hidden_nodes1': 246, 'hidden_nodes2': 166, 'hidden_nodes3': 379, 'hidden_nodes4': 291, 'hidden_nodes5': 459, 'hidden_nodes6': 189, 'hidden_nodes7': 361, 'hidden_nodes8': 24, 'hidden_nodes9': 455, 'optimizer': 'RMSprop', 'lr': 0.0014660569202228585, 'epochs': 290, 'reg_coef': 0.0003900352776544445}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:03:37,567] Trial 14 finished with value: -0.009721496142446995 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 25, 'hidden_nodes1': 259, 'hidden_nodes2': 171, 'hidden_nodes3': 368, 'hidden_nodes4': 290, 'hidden_nodes5': 512, 'hidden_nodes6': 183, 'hidden_nodes7': 353, 'hidden_nodes8': 8, 'hidden_nodes9': 509, 'optimizer': 'SGD', 'lr': 0.0001593596971063125, 'epochs': 204, 'reg_coef': 0.00010341997649798899}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:06:12,238] Trial 15 finished with value: -0.0026498688384890556 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 350, 'hidden_nodes1': 201, 'hidden_nodes2': 123, 'hidden_nodes3': 417, 'hidden_nodes4': 206, 'hidden_nodes5': 375, 'hidden_nodes6': 182, 'hidden_nodes7': 274, 'optimizer': 'RMSprop', 'lr': 0.02424785295548354, 'epochs': 275, 'reg_coef': 3.334741556399023e-05}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:08:25,610] Trial 16 finished with value: -0.014447183348238468 and parameters: {'n_layers': 9, 'active': False, 'hidden_nodes0': 388, 'hidden_nodes1': 327, 'hidden_nodes2': 209, 'hidden_nodes3': 142, 'hidden_nodes4': 351, 'hidden_nodes5': 249, 'hidden_nodes6': 138, 'hidden_nodes7': 352, 'hidden_nodes8': 153, 'optimizer': 'SGD', 'lr': 0.001792953854662151, 'epochs': 213, 'reg_coef': 0.011202699870565684}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:10:44,678] Trial 17 finished with value: -0.001234025345183909 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 232, 'hidden_nodes1': 45, 'hidden_nodes2': 76, 'hidden_nodes3': 346, 'hidden_nodes4': 140, 'hidden_nodes5': 443, 'hidden_nodes6': 290, 'optimizer': 'SGD', 'lr': 0.012055854793334698, 'epochs': 278, 'reg_coef': 0.0005723703744786664}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:12:03,292] Trial 18 finished with value: -0.006033926736563444 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 229, 'hidden_nodes1': 21, 'hidden_nodes2': 62, 'hidden_nodes3': 281, 'hidden_nodes4': 121, 'hidden_nodes5': 290, 'optimizer': 'SGD', 'lr': 0.01745732867684215, 'epochs': 171, 'reg_coef': 0.0027137409801226064}. Best is trial 3 with value: -0.0006798867252655327.
# [I 2024-01-11 21:14:12,577] Trial 19 finished with value: -0.0027810123283416033 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 317, 'hidden_nodes1': 15, 'hidden_nodes2': 290, 'hidden_nodes3': 329, 'hidden_nodes4': 47, 'hidden_nodes5': 417, 'hidden_nodes6': 337, 'optimizer': 'SGD', 'lr': 0.08966680406681243, 'epochs': 256, 'reg_coef': 0.09425382757436125}. Best is trial 3 with value: -0.0006798867252655327.
# {'n_layers': 9, 'active': False, 'hidden_nodes0': 362, 'hidden_nodes1': 327, 'hidden_nodes2': 27, 'hidden_nodes3': 106, 'hidden_nodes4': 160, 'hidden_nodes5': 410, 'hidden_nodes6': 29, 'hidden_nodes7': 270, 'hidden_nodes8': 47, 'optimizer': 'SGD', 'lr': 0.010414330376012897, 'epochs': 224, 'reg_coef': 0.012631112852290311}
# ===> training start
# [I 2024-01-11 21:14:37,018] A new study created in memory with name: no-name-0e10323f-38a4-4d97-919b-e44814271f24
# 2021-11-01 00:00:00
#    performance        ymd
# 0    -0.006119 2021-10-12
# param: {'batch_size': 25}
# cuda
# ===> tune start
# [I 2024-01-11 21:16:53,164] Trial 0 finished with value: -0.0014150241622701287 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 117, 'hidden_nodes1': 400, 'hidden_nodes2': 356, 'hidden_nodes3': 39, 'hidden_nodes4': 233, 'hidden_nodes5': 185, 'hidden_nodes6': 177, 'hidden_nodes7': 470, 'hidden_nodes8': 124, 'hidden_nodes9': 256, 'optimizer': 'SGD', 'lr': 5.7002708765860205e-05, 'epochs': 210, 'reg_coef': 3.252278814701912e-05}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:18:18,405] Trial 1 finished with value: -0.00918077863752842 and parameters: {'n_layers': 4, 'active': True, 'hidden_nodes0': 315, 'hidden_nodes1': 479, 'hidden_nodes2': 273, 'hidden_nodes3': 512, 'optimizer': 'SGD', 'lr': 0.0012947743695520765, 'epochs': 217, 'reg_coef': 3.500872689070547e-05}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:19:45,433] Trial 2 finished with value: -0.019675474613904953 and parameters: {'n_layers': 6, 'active': True, 'hidden_nodes0': 73, 'hidden_nodes1': 315, 'hidden_nodes2': 140, 'hidden_nodes3': 201, 'hidden_nodes4': 455, 'hidden_nodes5': 449, 'optimizer': 'RMSprop', 'lr': 0.08740930839681234, 'epochs': 178, 'reg_coef': 0.00026608476854608136}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:21:03,295] Trial 3 finished with value: -0.02454238384962082 and parameters: {'n_layers': 3, 'active': True, 'hidden_nodes0': 420, 'hidden_nodes1': 177, 'hidden_nodes2': 11, 'optimizer': 'RMSprop', 'lr': 0.002397843132297881, 'epochs': 232, 'reg_coef': 1.9650992931378147e-05}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:21:55,127] Trial 4 finished with value: -0.004314138554036617 and parameters: {'n_layers': 1, 'active': False, 'hidden_nodes0': 13, 'optimizer': 'RMSprop', 'lr': 0.0022889032490194822, 'epochs': 248, 'reg_coef': 0.0034751800983566093}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:23:36,391] Trial 5 finished with value: -0.0029033783357590437 and parameters: {'n_layers': 6, 'active': False, 'hidden_nodes0': 496, 'hidden_nodes1': 421, 'hidden_nodes2': 497, 'hidden_nodes3': 318, 'hidden_nodes4': 100, 'hidden_nodes5': 402, 'optimizer': 'RMSprop', 'lr': 0.0003560071503668795, 'epochs': 214, 'reg_coef': 0.000288791649230752}. Best is trial 0 with value: -0.0014150241622701287.
# [I 2024-01-11 21:24:30,586] Trial 6 finished with value: -0.0005912432679906487 and parameters: {'n_layers': 2, 'active': True, 'hidden_nodes0': 14, 'hidden_nodes1': 149, 'optimizer': 'SGD', 'lr': 2.196253654465183e-05, 'epochs': 188, 'reg_coef': 0.0006127674573887645}. Best is trial 6 with value: -0.0005912432679906487.
# [I 2024-01-11 21:25:47,274] Trial 7 finished with value: -0.0006201202631928027 and parameters: {'n_layers': 2, 'active': False, 'hidden_nodes0': 105, 'hidden_nodes1': 507, 'optimizer': 'Adam', 'lr': 0.0027192055807831266, 'epochs': 275, 'reg_coef': 0.002775770952814775}. Best is trial 6 with value: -0.0005912432679906487.
# [I 2024-01-11 21:27:07,958] Trial 8 finished with value: -0.0006053403485566378 and parameters: {'n_layers': 7, 'active': False, 'hidden_nodes0': 471, 'hidden_nodes1': 64, 'hidden_nodes2': 94, 'hidden_nodes3': 142, 'hidden_nodes4': 180, 'hidden_nodes5': 258, 'hidden_nodes6': 240, 'optimizer': 'Adam', 'lr': 0.03249198292363363, 'epochs': 161, 'reg_coef': 0.0008091316036923748}. Best is trial 6 with value: -0.0005912432679906487.
# [I 2024-01-11 21:29:09,127] Trial 9 finished with value: -0.0013145817210897803 and parameters: {'n_layers': 10, 'active': False, 'hidden_nodes0': 472, 'hidden_nodes1': 442, 'hidden_nodes2': 233, 'hidden_nodes3': 350, 'hidden_nodes4': 21, 'hidden_nodes5': 465, 'hidden_nodes6': 220, 'hidden_nodes7': 335, 'hidden_nodes8': 213, 'hidden_nodes9': 176, 'optimizer': 'Adam', 'lr': 2.8304897832149734e-05, 'epochs': 187, 'reg_coef': 0.056126309375738606}. Best is trial 6 with value: -0.0005912432679906487.
# [I 2024-01-11 21:30:08,691] Trial 10 finished with value: -0.015213415957987309 and parameters: {'n_layers': 4, 'active': True, 'hidden_nodes0': 246, 'hidden_nodes1': 14, 'hidden_nodes2': 459, 'hidden_nodes3': 505, 'optimizer': 'SGD', 'lr': 1.4611566005314811e-05, 'epochs': 152, 'reg_coef': 0.03463479262935238}. Best is trial 6 with value: -0.0005912432679906487.
# [I 2024-01-11 21:31:39,298] Trial 11 pruned.
# [I 2024-01-11 21:33:19,244] Trial 12 finished with value: -0.0013595204800367355 and parameters: {'n_layers': 8, 'active': False, 'hidden_nodes0': 187, 'hidden_nodes1': 85, 'hidden_nodes2': 122, 'hidden_nodes3': 182, 'hidden_nodes4': 225, 'hidden_nodes5': 243, 'hidden_nodes6': 31, 'hidden_nodes7': 7, 'optimizer': 'SGD', 'lr': 0.015065375365681224, 'epochs': 179, 'reg_coef': 0.007598040821406362}. Best is trial 6 with value: -0.0005912432679906487.

# %% [markdown]
# Ensemble method

# %%
# Ensemble method

# add all result from models
for i in models:
    if i < 8:
        model_name = models[i]
        performance_rolling, rplsw_rolling, market_rolling  = \
            models_get_result(industry, model_name, model_config) 
    else:
        break
    if i == 1:
        rplsw_rolling_ensem = rplsw_rolling
    else:
        rplsw_rolling_ensem["pred_ls"] += rplsw_rolling["pred_ls"]


rplsw_rolling_ensem.reset_index(inplace=True)

# %%
# backtest returns for ensemble
def ensem_backtest(rplsw_rolling_ensem):
    rplsw_rolling_ensem = rplsw_rolling_ensem.copy()
    long = rplsw_rolling_ensem[rplsw_rolling_ensem["pred_ls"] >= 3]
    short = rplsw_rolling_ensem[rplsw_rolling_ensem["pred_ls"] <= -3]

    if len(long) != 0 and len(short) != 0:
        long_rate = .5
        short_rate = .5
    elif len(long) != 0 and len(short) == 0:
        long_rate = 1
        short_rate = 0
    elif len(long) == 0 and len(short) != 0:
        long_rate = 0
        short_rate = 1
    else:
        print("No long or short")
        return 0

    long["ensem_weight"] = (long["pred_ls"] / long["pred_ls"].sum())*long_rate
    short["ensem_weight"] = (short["pred_ls"] / short["pred_ls"].sum())*short_rate
    print(f"check weight: {long['ensem_weight'].sum() + short['ensem_weight'].sum()}")
    ensem_return = (long["ensem_weight"]*long["return"]).sum() - (short["ensem_weight"]*short["return"]).sum()
    return ensem_return

ensem_returns = {}
for date in rplsw_rolling_ensem["ymd"].unique():
    ensem_returns[date] = ensem_backtest(rplsw_rolling_ensem[rplsw_rolling_ensem["ymd"] == date])

plt.plot(np.cumprod([i + 1 for i in list(ensem_returns.values())]))
m = np.mean(list(ensem_returns.values()))*12
v = np.std(list(ensem_returns.values()))*(12**(1/2))
m, v, m/v
# Out:
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 0.9999999999999999
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0
# check weight: 1.0

# %% [markdown]
# ### Backtest
# - result file in: result/industry/

# %%
# Check if short success
model_name = models[7]
performance_rolling, rplsw_rolling, market_rolling  = \
    models_get_result(industry, model_name, model_config) 
(rplsw_rolling["pred_ls"] == -1).sum()
# Out:
# 202

# %%
industry = "automobile"
models = {1: "linear",
         2: "elastic net",
         3: "decision tree", 
         4: "random forest", 
         5: "xgboost", 
         6: "svm", 
         7: "neural network",
         8: "ensemble",
         }

model_config = \
        {
        "industry": "automobile",
        "train_size": 5,    
        "test_size": 1,     
        "test_start": 2021,  

        "long_bound": 80,       
        "short_bound": 20,        
        "ls_decision": ["test", "no running"],
        "n_trials": 1,      
        "tune": True,
        "do_short": True, 
        "input_size": 89   # = input size | original dimension = input_size: 89
        }

for i in models:
    if i < 8:
        model_name = models[7]
        plot_model_result(industry, model_name, model_config)
        # performance_rolling rplsw_rolling, market_rolling, = \
        #    models_get_result(industry, model_name, model_config)        
        # n_long, n_short, trading_rate = trading(rplsw_rolling)
        break
# Out:
# market performance ==================
# market_mean: 0.1384795173451961, market_vol: 0.19459484931267879
# market: sharpe ratio 0.7116299215231772
